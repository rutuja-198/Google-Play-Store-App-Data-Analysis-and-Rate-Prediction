# %%
#import library
import pandas as pd #data processing and read the file
import numpy as np #mathematical operation on array
import matplotlib.pyplot as plt #plot or draw the graph
import seaborn as sns  #Data visualization and EDA

# %%
#read the CSV file using library
data = pd.read_csv("C:/Users/Admin/Desktop/Google Play Store Analysis/Google Play Store Apps Dataset/googleplaystore.csv")

# %%
#fetch the data from CSV file(data columns and data types)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#check data columns
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#fetch number of rows and column
data.shape
# Out:
# (10841, 13)

# %%
#fetch first 5 data
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite - FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#fetch last 5 data
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# #### Dataset can contain missing data, numerical string value, duplication etc.

# %% [markdown]
# ## 1. Category

# %%
#fetch unique value of category
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
#fetch the category which is  1.9
data[data['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#shift the category to NaN using shift function
data.loc[10472] = data.loc[10472].shift()
data['App'].loc[10472] = data['Category'].loc[10472]
data['Category'].loc[10472] = np.nan
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              NaN
# Rating                                                1.9
# Reviews                                              19.0
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %% [markdown]
# ## 2. Rating

# %%
# check data
data['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4.0, nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5.0, 2.6, 3.0, 1.9, 2.5, 2.8,
#        2.7, 1.0, 2.9, 2.3, 2.2, 1.7, 2.0, 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2, '1.9'], dtype=object)

# %%
#datatype is object so convert into numeric
data['Rating'] = pd.to_numeric(data['Rating'], errors='coerce')
data['Rating'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 3. Review

# %%
#check data
data['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
#replace the review in million and check data type
data['Reviews'] = data.Reviews.replace("0.0",0)
data['Reviews'] = data.Reviews.replace("3.0M",3000000.0)

# %%
data['Reviews'] = data['Reviews'].astype(float)
data['Reviews'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 4. Size

# %%
#check data
data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
data['Size'] = data.Size.replace("Varies with device",np.nan) #changed 'Varies with device' value with Nan
data['Size'] = data.Size.str.replace("M","000") # All size values became the kilobyte type.
data['Size'] = data.Size.str.replace("k","") 
data['Size'] = data.Size.replace("1,000+",1000)
data['Size'] =data['Size'].astype(float) #converted float value
data['Size'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 5. Installs

# %%
#check data
data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
#replace the strings and convert data type
data['Installs'] = data.Installs.str.replace(",","")
data['Installs'] = data.Installs.str.replace("+","")
data['Installs'] = data.Installs.replace("Free",np.nan)
data['Installs'] = data['Installs'].astype(float)
data['Installs'].dtype
# Out:
# <ipython-input-19-4ce90df0d6e7>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['Installs'] = data.Installs.str.replace("+","")
# dtype('float64')

# %% [markdown]
# ## 6. Price

# %%
#check data
data['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
data['Price'] = data.Price.replace("Everyone",np.nan)
data['Price'] = data.Price.str.replace("$","").astype(float)
data['Price'].dtype
# Out:
# <ipython-input-21-08d41fc5483d>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['Price'] = data.Price.str.replace("$","").astype(float)
# dtype('float64')

# %% [markdown]
# ## 7. Last Updated

# %%
#check data
data['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
#convert data type
data['Last Updated'] = pd.to_datetime(data['Last Updated'])
data['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %% [markdown]
# ## 8. Apps

# %%
#check data
data['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite - FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
#check any duplicate values
duplicate_val = data['App'].duplicated().any()
duplicate_val
# Out:
# True

# %%
data['App'].value_counts()
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# Candy Crush Saga                                     7
# 8 Ball Pool                                          7
# ESPN                                                 7
#                                                     ..
# Complete Anatomy for Android                         1
# Sago Mini Hat Maker                                  1
# Foothills CP                                         1
# CJ WOW SHOP                                          1
# Airplane Fly Hawaii                                  1
# Name: App, Length: 9660, dtype: int64

# %% [markdown]
# #### As we can see from the above mentioned data, some of the apps are having multiple rows.

# %%
data[data['App']=='ROBLOX']
# Out:
#          App Category  Rating    Reviews     Size     Installs  Type  Price  \
# 1653  ROBLOX     GAME     4.5  4447388.0  67000.0  100000000.0  Free    0.0
# 1701  ROBLOX     GAME     4.5  4447346.0  67000.0  100000000.0  Free    0.0
# 1748  ROBLOX     GAME     4.5  4448791.0  67000.0  100000000.0  Free    0.0
# 1841  ROBLOX     GAME     4.5  4449882.0  67000.0  100000000.0  Free    0.0
# 1870  ROBLOX     GAME     4.5  4449910.0  67000.0  100000000.0  Free    0.0
# 2016  ROBLOX   FAMILY     4.5  4449910.0  67000.0  100000000.0  Free    0.0
# 2088  ROBLOX   FAMILY     4.5  4450855.0  67000.0  100000000.0  Free    0.0
# 2206  ROBLOX   FAMILY     4.5  4450890.0  67000.0  100000000.0  Free    0.0
# 4527  ROBLOX   FAMILY     4.5  4443407.0  67000.0  100000000.0  Free    0.0
#
#      Content Rating                        Genres Last Updated   Current Ver  \
# 1653   Everyone 10+  Adventure;Action & Adventure   2018-07-31  2.347.225742
# ...

# %% [markdown]
# #### As we can see from the above dataframe, ROBLOX app is having identical rows with difference in number of reviews. It may have happened that for the same app, the data has been scraped in different points of time. So we have kept row of an app with maximum number of reviews, assuming it to be the latest one.

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Let’s plot a visualization graph to view what portion of the apps in the play store are paid and free.

# %% [markdown]
# ### 1. Percentage of Free vs Paid Apps in store

# %%
plt.figure(figsize=(10,10))
labels = data['Type'].value_counts(sort = True).index
sizes = data['Type'].value_counts(sort = True)
colors = ["blue","lightgreen"]
explode = (0.2,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# #### It can be conclude that the 92.6% is free application in play store and 7.4% is paid application in play store.

# %% [markdown]
# ### 2. Distribution of Rating

# %%
#distribution of the ratings
plt.figure(figsize=(15,9))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(data.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating',size = 20);

# %% [markdown]
# ### 3. Count of applications in each category differentiated by their type

# %%
count_of_apps = data.groupby(['Category','Type'])[['App']].count().reset_index().rename(columns={'App':'Count','index':'App'})
df_app_count = count_of_apps.pivot('Category', 'Type', 'Count').fillna(0).reset_index()
df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Count of applications in each category differentiated by their type")
plt.show()

# %% [markdown]
# #### It looks like certain app categories have more free apps available for download than others. In dataset, the majority of apps in Family, Food & Drink and Tools, as well as Social categories were free to install and at the same time Family, Sports, Tools and Medical categories had the biggest number of paid apps available for download.

# %% [markdown]
# ### 4. Total of installed apps according to its type

# %%
categoty_type = data.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type['log_Installed'] = np.log2(categoty_type['Installs'])
plt.figure(figsize = (18,9))
plt.xticks(rotation = 65,fontsize = 9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Category")
sns.barplot('Category', 'log_Installed', hue='Type', data=categoty_type);
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### It can be conclude that the number of free applications installed by the user are high when compared with the paid ones.

# %% [markdown]
# ### 5. Histogram of size

# %%
# to remove null values from size column
data.loc[data['Size'].isnull(),'Size']=0

# %%
#plot histogram
plt.xlabel("Size")
plt.title("Distribution of Size")
plt.hist(data['Size']);
plt.show()

# %% [markdown]
# #### From the above histogram, it can be concluded that maximum number of applications present in the dataset are of small size.

# %% [markdown]
# ### 6. Distribution plot of Installed Apps with 5.0 Ratings

# %%
app_rate = data[data.Rating == 5]
app_rate.head()
# Out:
#                                             App Category  Rating  Reviews  \
# 329                Hojiboy Tojiboyev Life Hacks   COMICS     5.0     15.0
# 612               American Girls Mobile Numbers   DATING     5.0      5.0
# 615                                Awake Dating   DATING     5.0      2.0
# 633                       Spine- The dating app   DATING     5.0      5.0
# 636  Girls Live Talk - Free Text and Video Chat   DATING     5.0      6.0
#
#         Size  Installs  Type  Price Content Rating  Genres Last Updated  \
# 329  37000.0    1000.0  Free    0.0       Everyone  Comics   2018-06-26
# 612      4.4    1000.0  Free    0.0     Mature 17+  Dating   2018-07-17
# 615  70000.0     100.0  Free    0.0     Mature 17+  Dating   2018-07-24
# 633      9.3     500.0  Free    0.0           Teen  Dating   2018-07-14
# 636      5.0     100.0  Free    0.0     Mature 17+  Dating   2018-08-01
#
#     Current Ver   Android Ver
# 329           2  4.0.3 and up
# ...

# %%
sns.distplot(app_rate.Installs)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Installs', ylabel='Density'>

# %%
app_rate.Installs.value_counts().sort_index()
# Out:
# 1.0          3
# 5.0          8
# 10.0        48
# 50.0        32
# 100.0      112
# 500.0       27
# 1000.0      37
# 5000.0       3
# 10000.0      1
# Name: Installs, dtype: int64

# %% [markdown]
# #### here we conclude that many Apps that have full ratings but less downloads/installs. So we can't really consider those apps as the best ones.

# %%
# check the number of review
sns.distplot(app_rate.Reviews)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %% [markdown]
# #### Here we can conclude that apps with very few reviews easily managed to get 5.0 ratings.

# %% [markdown]
# ### 7. Count of Content Rating

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data, x='Content Rating')
plt.xticks(rotation=80)
plt.title('Content Rating',color = 'blue',fontsize=15)
plt.show()

# %% [markdown]
# ### 8. Top 20 apps as per Genre

# %%
top_genres = data.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})

# %%
genres_installs = data.groupby(['Genres'])[['Installs']].sum()

# %%
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 apps by Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 9. Count of app for each category and number of installed application for each category

# %%
cnt_category = data.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})

# %%
category_installs = data.groupby(['Category'])[['Installs']].sum()

# %%
cnt_category_installs = pd.merge(cnt_category, category_installs, on='Category')
cnt_category_installs_app = cnt_category_installs

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of application")
plt.title("Count of applications for each Category")
sns.barplot(cnt_category_installs_app.Category, cnt_category_installs_app.Count)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed applications for each Category")
sns.barplot(cnt_category_installs_app.Category, cnt_category_installs_app.Installs)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### As we can see from the above two plots: Maxinum number of apps present in google play store comes under Family, Games and Tools Category but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Games,  Communication and Tools.

# %% [markdown]
# ### 10. Which are the Genres that are getting installed the most in top 20 Genres?

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 11. Count the various android version

# %%
data['Android Ver'].value_counts()
# Out:
# 4.1 and up            2379
# 4.0.3 and up          1451
# 4.0 and up            1338
# Varies with device    1221
# 4.4 and up             894
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 1.0 and up               2
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 2.2 - 7.1.1              1
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 7.1.1              1
# 5.0 - 6.0                1
# Name: Android Ver, dtype: int64

# %%
new_ver = []

for row in data['Android Ver']:
    try:
        new_row = float(row[:2])
    except:
        new_row = 0  # When the value is - Varies with device
    
    new_ver.append(new_row)
    
data['Android Ver'] =  new_ver

data['Android Ver'].value_counts()
# Out:
# 4.0    6698
# 2.0    1334
# 0.0    1223
# 5.0     572
# 3.0     283
# 1.0     138
# 6.0      58
# 7.0      46
# 8.0       6
# Name: Android Ver, dtype: int64

# %%
sns.countplot(data['Android Ver'])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Android Ver', ylabel='count'>

# %% [markdown]
# #### We can conclude that Most of the apps support Android 4.0 and above are less using users.

# %% [markdown]
# ## 12. Show that which app is costly

# %%
data[data.Price == data.Price.max()]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7.3   10000.0
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle   2018-05-03       1.0.1
#
#       Android Ver
# 4367          4.0

# %% [markdown]
# #### We can conclude that the most costly App in the Store is: I'm Rich - Trump Edition costing 400 Dollars

# %% [markdown]
# ## Analysis on Google Play Store Review

# %%
user_review_data = pd.read_csv("C:/Users/Admin/Desktop/Google Play Store Analysis/Google Play Store Apps Dataset/googleplaystore_user_reviews.csv")

# %%
#merge dataframes on apps
merged_data = data.merge(user_review_data, on="App")

# %% [markdown]
# ### Distribution of type of reviews in the dataset

# %%
category_sentiment = merged_data.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')

# %%
category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=90,fontsize=11)
plt.xlabel("Category", fontsize=15)
plt.ylabel("Installs", fontsize=15)
plt.title("Number of installs type wise according to Genres",fontsize=15)
sns.barplot('Category', 'log_sentiment_count', hue='Sentiment', data=category_sentiment);
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Percentage of Review Sentiments

# %%
import matplotlib
counts = list(merged_data['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (10, 10)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentiments', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# ### Correlation

# %%
data.corr()
# Out:
#                Rating   Reviews      Size  Installs     Price  Android Ver
# Rating       1.000000  0.068738  0.050298  0.050925 -0.022301    -0.020752
# Reviews      0.068738  1.000000  0.077222  0.634998 -0.009416    -0.116050
# Size         0.050298  0.077222  1.000000  0.011685 -0.016149     0.264444
# Installs     0.050925  0.634998  0.011685  1.000000 -0.011146    -0.180725
# Price       -0.022301 -0.009416 -0.016149 -0.011146  1.000000     0.018429
# Android Ver -0.020752 -0.116050  0.264444 -0.180725  0.018429     1.000000

# %%
#correlation map
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
